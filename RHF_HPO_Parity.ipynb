# %% [markdown]
# Objective
#  - To compare the two parity plots
#
#     (a) First-principle vs. operational data
#
#     (b) Hybrid model vs. operational data.
#
# - Step 1. Import origianl data set
# - Step 2. Prediction (RHF-HPO model)

# %%
import pandas as pd
import numpy as np
from pycaret.regression import *

# %%
# %pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\Jinsu Kim\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
Model_M = load_model ('Tuend_XGB_M')
Model_Z = load_model ('Tuend_XGB_Z')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# [11:07:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:1040:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [11:07:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:749: Found JSON model saved before XGBoost 1.6, please save the model using current version again. The support for old JSON model will be discontinued in XGBoost 2.3.
# [11:07:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:438:
# ...

# %%
raw_df = pd.read_csv('Op_feed_composition.csv')/100

raw_df.head(5)
# Out:
#       TFe     MFe     FeO   Fe2O3       C       Zn
# 0  0.4929  0.0689  0.2733  0.3025  0.0986  0.02237
# 1  0.4884  0.0672  0.2636  0.3092  0.0985  0.02251
# 2  0.4999  0.0646  0.2706  0.3216  0.0948  0.02224
# 3  0.4984  0.0680  0.2832  0.3006  0.0967  0.02406
# 4  0.4956  0.0632  0.2888  0.2973  0.0960  0.02355

# %%
prediction_M = predict_model (Model_M, data = raw_df)
prediction_Z = predict_model (Model_Z, data = raw_df)

# %%
save_csv_M = pd.DataFrame(prediction_M).to_csv('Result_HPO_M.csv')
save_csv_Z = pd.DataFrame(prediction_Z).to_csv('Result_HPO_Z.csv')
